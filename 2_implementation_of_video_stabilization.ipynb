# %% [markdown]
# # Digital Video Stabilization

# %% [markdown]
# This notebook explores state of the art methods of video stabilization. It benchmarks these methods on a specific dataset of shaky videos (from tennis table matches and swimming competitions). Then, we propose some innovative ideas and compare them with these methods.
#
# We will proceed as follows :
#
#
# *   Video stabilization definition and examples ( real shaky + artificially generated distabilized videos).
# *   State of the art methods.

# %%
# !unzip samples.zip
# Out:
# Archive:  samples.zip
#    creating: samples/
#   inflating: samples/vibrate_randomly.mp4
#   inflating: samples/vibrate_up_down.mp4
#   inflating: samples/video_after_rotation.mp4
#   inflating: samples/video_after_translation.mp4
#   inflating: samples/videoplayback.mp4
#   inflating: samples/vibration.mp4

# %%
# !pip install vidstab
# !apt install ffmpeg
import numpy as np
import cv2
import vidstab
import matplotlib.pyplot as plt
import imageio
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import os
# Out:
# Requirement already satisfied: vidstab in /usr/local/lib/python3.10/dist-packages (1.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vidstab) (1.23.5)
# Requirement already satisfied: imutils>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from vidstab) (0.5.4)
# Requirement already satisfied: progress in /usr/local/lib/python3.10/dist-packages (from vidstab) (1.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from vidstab) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->vidstab) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->vidstab) (1.16.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %% [markdown]
# # Generate destabilized videos
#
# ## Rotation

# %%
def rotate(frame, angle):
    cols, rows, _ = frame.shape
    rotate_around = (cols // 2, rows // 2)
    rot_mat = cv2.getRotationMatrix2D(rotate_around, angle, 1.0)
    result = cv2.warpAffine(frame, rot_mat, frame.shape[1::-1], flags=cv2.INTER_LINEAR)
    return result


def rotate_video(video_path_in, video_name, rotation_increment, video_path_out):
    video = os.path.join(video_path_in, video_name)
    video = cv2.VideoCapture(video)
    fourcc = cv2.VideoWriter_fourcc("M", "J", "P", "G")
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)
    video_writer = cv2.VideoWriter(video_path_out, fourcc, fps, (width, height))
    while True:
        ret, frame = video.read()
        if not ret:
            break
        direction = np.random.choice([-1, 1])
        result = rotate(frame, rotation_increment * direction)
        rotation_increment = rotation_increment * direction
        video_writer.write(result)
    video_writer.release()
    video.release()

# %% [markdown]
# ## Translation

# %%
def translate_vertically(frame, translation_rate):
    frame1 = np.zeros(frame.shape)
    h, w, _ = frame.shape

    if translation_rate > 0:
        frame1[translation_rate:h, :] = frame[: h - translation_rate, :]
    else:
        frame1[: h - translation_rate, :] = frame[translation_rate:h, :]
    return frame1


def translate_horizontally(frame, translation_rate):
    frame1 = np.zeros_like(frame)
    h, w, _ = frame.shape

    if translation_rate > 0:
        frame1[:, translation_rate:w] = frame[:, : w - translation_rate]
    else:
        frame1[:, : w - translation_rate] = frame[:, translation_rate:w]
    return frame1


def translate_video_horizontally(
    video_path_in, video_name, translation_rate, video_path_out
):
    video = os.path.join(video_path_in, video_name)

    video = cv2.VideoCapture(video)
    fourcc = cv2.VideoWriter_fourcc("M", "J", "P", "G")
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)
    video_writer = cv2.VideoWriter(video_path_out, fourcc, fps, (width, height))
    while True:
        ret, frame = video.read()
        if not ret:
            break
        result = translate_horizontally(frame, translation_rate)
        translation_rate += 5
        video_writer.write(result)
    video_writer.release()
    video.release()


def translate_video_vertically(
    video_path_in, video_name, translation_rate, video_path_out
):
    video = os.path.join(video_path_in, video_name)

    video = cv2.VideoCapture(video)
    fourcc = cv2.VideoWriter_fourcc("M", "J", "P", "G")
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)
    video_writer = cv2.VideoWriter(video_path_out, fourcc, fps, (width, height))
    while True:
        ret, frame = video.read()
        if not ret:
            break
        result = translate_vertically(frame, translation_rate)
        translation_rate += 5
        video_writer.write(result)
    video_writer.release()
    video.release()

# %% [markdown]
# ## Destabilize with random translation

# %%
import numpy as np
from moviepy.editor import VideoClip


def shake_video_randomly(video_path_in, video_name, shake_intensity, video_path_out):
    video = os.path.join(video_path_in, video_name)
    video = cv2.VideoCapture(video)
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)
    video_writer = cv2.VideoWriter(video_path_out, fourcc, fps, (width, height))
    while True:
        ret, frame = video.read()
        if not ret:
            break
        h, w, _ = frame.shape
        direction = np.random.choice(["up","left","right","down"])
        frame1 = np.zeros_like(frame)
        if direction == "up":
            frame1[: h - shake_intensity] = frame[shake_intensity:h]
        elif direction == "left":
            frame1[:, : w - shake_intensity] = frame[:, shake_intensity:w]
        elif direction == "down":
            frame1[shake_intensity:h] = frame[: h - shake_intensity]
        else:
            frame1[:, shake_intensity:w] = frame[:, : w - shake_intensity]
        video_writer.write(frame1)
    video_writer.release()
    video.release()

# %% [markdown]
# # Video Stabilization Using Point Feature Matching in OpenCV

# %%
from Point_Feature_Matching_opencv import stabilize_point_feature_match
videos=os.listdir("./samples")
for video in videos:
  input_file=os.path.join("./samples",video)
  output_file=os.path.join("./opencv",video.replace(".mp4","_stabilized.mp4"))
  stabilize_point_feature_match(input_file,output_file)
# Out:
# Frame: 0/100 -  Tracked points : 200
# Frame: 1/100 -  Tracked points : 200
# Frame: 2/100 -  Tracked points : 189
# Frame: 3/100 -  Tracked points : 200
# Frame: 4/100 -  Tracked points : 174
# Frame: 5/100 -  Tracked points : 200
# Frame: 6/100 -  Tracked points : 188
# Frame: 7/100 -  Tracked points : 176
# Frame: 8/100 -  Tracked points : 200
# Frame: 9/100 -  Tracked points : 200
# Frame: 10/100 -  Tracked points : 188
# Frame: 11/100 -  Tracked points : 200
# Frame: 12/100 -  Tracked points : 184
# Frame: 13/100 -  Tracked points : 187
# Frame: 14/100 -  Tracked points : 200
# Frame: 15/100 -  Tracked points : 200
# Frame: 16/100 -  Tracked points : 200
# Frame: 17/100 -  Tracked points : 200
# Frame: 18/100 -  Tracked points : 200
# Frame: 19/100 -  Tracked points : 200
# Frame: 20/100 -  Tracked points : 200
# Frame: 21/100 -  Tracked points : 200
# Frame: 22/100 -  Tracked points : 200
# Frame: 23/100 -  Tracked points : 200
# Frame: 24/100 -  Tracked points : 200
# Frame: 25/100 -  Tracked points : 183
# Frame: 26/100 -  Tracked points : 200
# Frame: 27/100 -  Tracked points : 184
# Frame: 28/100 -  Tracked points : 182
# Frame: 29/100 -  Tracked points : 188
# Frame: 30/100 -  Tracked points : 184
# Frame: 31/100 -  Tracked points : 200
# Frame: 32/100 -  Tracked points : 186
# Frame: 33/100 -  Tracked points : 182
# Frame: 34/100 -  Tracked points : 200
# Frame: 35/100 -  Tracked points : 183
# Frame: 36/100 -  Tracked points : 200
# Frame: 37/100 -  Tracked points : 183
# Frame: 38/100 -  Tracked points : 184
# Frame: 39/100 -  Tracked points : 181
# Frame: 40/100 -  Tracked points : 189
# Frame: 41/100 -  Tracked points : 181
# Frame: 42/100 -  Tracked points : 186
# Frame: 43/100 -  Tracked points : 182
# Frame: 44/100 -  Tracked points : 200
# Frame: 45/100 -  Tracked points : 187
# Frame: 46/100 -  Tracked points : 200
# Frame: 47/100 -  Tracked points : 180
# Frame: 48/100 -  Tracked points : 188
# Frame: 49/100 -  Tracked points : 200
# Frame: 50/100 -  Tracked points : 200
# Frame: 51/100 -  Tracked points : 200
# Frame: 52/100 -  Tracked points : 185
# Frame: 53/100 -  Tracked points : 200
# Frame: 54/100 -  Tracked points : 200
# Frame: 55/100 -  Tracked points : 200
# Frame: 56/100 -  Tracked points : 200
# Frame: 57/100 -  Tracked points : 189
# Frame: 58/100 -  Tracked points : 185
# Frame: 59/100 -  Tracked points : 187
# Frame: 60/100 -  Tracked points : 200
# Frame: 61/100 -  Tracked points : 183
# Frame: 62/100 -  Tracked points : 200
# Frame: 63/100 -  Tracked points : 200
# Frame: 64/100 -  Tracked points : 184
# Frame: 65/100 -  Tracked points : 200
# Frame: 66/100 -  Tracked points : 200
# Frame: 67/100 -  Tracked points : 200
# Frame: 68/100 -  Tracked points : 200
# Frame: 69/100 -  Tracked points : 200
# Frame: 70/100 -  Tracked points : 200
# Frame: 71/100 -  Tracked points : 185
# Frame: 72/100 -  Tracked points : 188
# Frame: 73/100 -  Tracked points : 182
# Frame: 74/100 -  Tracked points : 192
# Frame: 75/100 -  Tracked points : 182
# Frame: 76/100 -  Tracked points : 189
# Frame: 77/100 -  Tracked points : 200
# Frame: 78/100 -  Tracked points : 200
# Frame: 79/100 -  Tracked points : 185
# Frame: 80/100 -  Tracked points : 190
# Frame: 81/100 -  Tracked points : 184
# Frame: 82/100 -  Tracked points : 189
# Frame: 83/100 -  Tracked points : 200
# Frame: 84/100 -  Tracked points : 200
# Frame: 85/100 -  Tracked points : 183
# Frame: 86/100 -  Tracked points : 200
# Frame: 87/100 -  Tracked points : 200
# Frame: 88/100 -  Tracked points : 200
# Frame: 89/100 -  Tracked points : 184
# Frame: 90/100 -  Tracked points : 200
# Frame: 91/100 -  Tracked points : 200
# Frame: 92/100 -  Tracked points : 184
# Frame: 93/100 -  Tracked points : 187
# Frame: 94/100 -  Tracked points : 184
# Frame: 95/100 -  Tracked points : 200
# Frame: 96/100 -  Tracked points : 188
# Frame: 97/100 -  Tracked points : 182
# Frame: 0/100 -  Tracked points : 167
# Frame: 1/100 -  Tracked points : 200
# Frame: 2/100 -  Tracked points : 200
# Frame: 3/100 -  Tracked points : 178
# Frame: 4/100 -  Tracked points : 183
# Frame: 5/100 -  Tracked points : 174
# Frame: 6/100 -  Tracked points : 200
# Frame: 7/100 -  Tracked points : 177
# Frame: 8/100 -  Tracked points : 186
# Frame: 9/100 -  Tracked points : 173
# Frame: 10/100 -  Tracked points : 173
# Frame: 11/100 -  Tracked points : 200
# Frame: 12/100 -  Tracked points : 200
# Frame: 13/100 -  Tracked points : 200
# Frame: 14/100 -  Tracked points : 189
# Frame: 15/100 -  Tracked points : 200
# Frame: 16/100 -  Tracked points : 177
# Frame: 17/100 -  Tracked points : 179
# Frame: 18/100 -  Tracked points : 200
# Frame: 19/100 -  Tracked points : 200
# Frame: 20/100 -  Tracked points : 178
# Frame: 21/100 -  Tracked points : 200
# Frame: 22/100 -  Tracked points : 176
# Frame: 23/100 -  Tracked points : 190
# Frame: 24/100 -  Tracked points : 178
# Frame: 25/100 -  Tracked points : 187
# Frame: 26/100 -  Tracked points : 183
# Frame: 27/100 -  Tracked points : 181
# Frame: 28/100 -  Tracked points : 179
# Frame: 29/100 -  Tracked points : 180
# Frame: 30/100 -  Tracked points : 180
# Frame: 31/100 -  Tracked points : 200
# Frame: 32/100 -  Tracked points : 180
# Frame: 33/100 -  Tracked points : 182
# Frame: 34/100 -  Tracked points : 181
# Frame: 35/100 -  Tracked points : 177
# Frame: 36/100 -  Tracked points : 180
# Frame: 37/100 -  Tracked points : 178
# Frame: 38/100 -  Tracked points : 187
# Frame: 39/100 -  Tracked points : 175
# Frame: 40/100 -  Tracked points : 183
# Frame: 41/100 -  Tracked points : 200
# Frame: 42/100 -  Tracked points : 200
# Frame: 43/100 -  Tracked points : 187
# Frame: 44/100 -  Tracked points : 200
# Frame: 45/100 -  Tracked points : 182
# Frame: 46/100 -  Tracked points : 200
# Frame: 47/100 -  Tracked points : 173
# Frame: 48/100 -  Tracked points : 185
# Frame: 49/100 -  Tracked points : 180
# Frame: 50/100 -  Tracked points : 188
# Frame: 51/100 -  Tracked points : 183
# Frame: 52/100 -  Tracked points : 200
# Frame: 53/100 -  Tracked points : 200
# Frame: 54/100 -  Tracked points : 180
# Frame: 55/100 -  Tracked points : 180
# Frame: 56/100 -  Tracked points : 189
# Frame: 57/100 -  Tracked points : 182
# Frame: 58/100 -  Tracked points : 178
# Frame: 59/100 -  Tracked points : 183
# Frame: 60/100 -  Tracked points : 179
# Frame: 61/100 -  Tracked points : 188
# Frame: 62/100 -  Tracked points : 200
# Frame: 63/100 -  Tracked points : 180
# Frame: 64/100 -  Tracked points : 181
# Frame: 65/100 -  Tracked points : 200
# Frame: 66/100 -  Tracked points : 179
# Frame: 67/100 -  Tracked points : 188
# Frame: 68/100 -  Tracked points : 180
# Frame: 69/100 -  Tracked points : 177
# Frame: 70/100 -  Tracked points : 200
# Frame: 71/100 -  Tracked points : 187
# Frame: 72/100 -  Tracked points : 178
# Frame: 73/100 -  Tracked points : 189
# Frame: 74/100 -  Tracked points : 182
# Frame: 75/100 -  Tracked points : 190
# Frame: 76/100 -  Tracked points : 178
# Frame: 77/100 -  Tracked points : 178
# Frame: 78/100 -  Tracked points : 188
# Frame: 79/100 -  Tracked points : 180
# Frame: 80/100 -  Tracked points : 182
# Frame: 81/100 -  Tracked points : 178
# Frame: 82/100 -  Tracked points : 178
# Frame: 83/100 -  Tracked points : 189
# Frame: 84/100 -  Tracked points : 200
# Frame: 85/100 -  Tracked points : 180
# Frame: 86/100 -  Tracked points : 183
# Frame: 87/100 -  Tracked points : 178
# Frame: 88/100 -  Tracked points : 200
# Frame: 89/100 -  Tracked points : 189
# Frame: 90/100 -  Tracked points : 179
# Frame: 91/100 -  Tracked points : 200
# Frame: 92/100 -  Tracked points : 178
# Frame: 93/100 -  Tracked points : 200
# Frame: 94/100 -  Tracked points : 190
# Frame: 95/100 -  Tracked points : 179
# Frame: 96/100 -  Tracked points : 200
# Frame: 97/100 -  Tracked points : 180
# Frame: 0/100 -  Tracked points : 200
# Frame: 1/100 -  Tracked points : 200
# Frame: 2/100 -  Tracked points : 148
# Frame: 3/100 -  Tracked points : 200
# Frame: 4/100 -  Tracked points : 200
# Frame: 5/100 -  Tracked points : 200
# Frame: 6/100 -  Tracked points : 164
# Frame: 7/100 -  Tracked points : 200
# Frame: 8/100 -  Tracked points : 200
# Frame: 9/100 -  Tracked points : 143
# Frame: 10/100 -  Tracked points : 144
# Frame: 11/100 -  Tracked points : 200
# Frame: 12/100 -  Tracked points : 150
# Frame: 13/100 -  Tracked points : 200
# Frame: 14/100 -  Tracked points : 200
# Frame: 15/100 -  Tracked points : 200
# Frame: 16/100 -  Tracked points : 200
# Frame: 17/100 -  Tracked points : 166
# Frame: 18/100 -  Tracked points : 147
# Frame: 19/100 -  Tracked points : 200
# Frame: 20/100 -  Tracked points : 167
# Frame: 21/100 -  Tracked points : 200
# Frame: 22/100 -  Tracked points : 153
# Frame: 23/100 -  Tracked points : 164
# Frame: 24/100 -  Tracked points : 150
# Frame: 25/100 -  Tracked points : 159
# Frame: 26/100 -  Tracked points : 149
# Frame: 27/100 -  Tracked points : 200
# Frame: 28/100 -  Tracked points : 200
# Frame: 29/100 -  Tracked points : 168
# Frame: 30/100 -  Tracked points : 200
# Frame: 31/100 -  Tracked points : 157
# Frame: 32/100 -  Tracked points : 161
# Frame: 33/100 -  Tracked points : 153
# Frame: 34/100 -  Tracked points : 163
# Frame: 35/100 -  Tracked points : 200
# Frame: 36/100 -  Tracked points : 200
# Frame: 37/100 -  Tracked points : 160
# Frame: 38/100 -  Tracked points : 165
# Frame: 39/100 -  Tracked points : 148
# Frame: 40/100 -  Tracked points : 200
# Frame: 41/100 -  Tracked points : 168
# Frame: 42/100 -  Tracked points : 151
# Frame: 43/100 -  Tracked points : 161
# Frame: 44/100 -  Tracked points : 200
# Frame: 45/100 -  Tracked points : 200
# Frame: 46/100 -  Tracked points : 200
# Frame: 47/100 -  Tracked points : 200
# Frame: 48/100 -  Tracked points : 200
# Frame: 49/100 -  Tracked points : 160
# Frame: 50/100 -  Tracked points : 164
# Frame: 51/100 -  Tracked points : 152
# Frame: 52/100 -  Tracked points : 200
# Frame: 53/100 -  Tracked points : 200
# Frame: 54/100 -  Tracked points : 171
# Frame: 55/100 -  Tracked points : 200
# Frame: 56/100 -  Tracked points : 200
# Frame: 57/100 -  Tracked points : 154
# Frame: 58/100 -  Tracked points : 200
# Frame: 59/100 -  Tracked points : 200
# Frame: 60/100 -  Tracked points : 200
# Frame: 61/100 -  Tracked points : 169
# Frame: 62/100 -  Tracked points : 145
# Frame: 63/100 -  Tracked points : 163
# Frame: 64/100 -  Tracked points : 200
# Frame: 65/100 -  Tracked points : 148
# Frame: 66/100 -  Tracked points : 200
# Frame: 67/100 -  Tracked points : 164
# Frame: 68/100 -  Tracked points : 200
# Frame: 69/100 -  Tracked points : 200
# Frame: 70/100 -  Tracked points : 153
# Frame: 71/100 -  Tracked points : 154
# Frame: 72/100 -  Tracked points : 150
# Frame: 73/100 -  Tracked points : 159
# Frame: 74/100 -  Tracked points : 200
# Frame: 75/100 -  Tracked points : 161
# Frame: 76/100 -  Tracked points : 200
# Frame: 77/100 -  Tracked points : 166
# Frame: 78/100 -  Tracked points : 200
# Frame: 79/100 -  Tracked points : 200
# Frame: 80/100 -  Tracked points : 151
# Frame: 81/100 -  Tracked points : 160
# Frame: 82/100 -  Tracked points : 200
# Frame: 83/100 -  Tracked points : 165
# Frame: 84/100 -  Tracked points : 200
# Frame: 85/100 -  Tracked points : 200
# Frame: 86/100 -  Tracked points : 200
# Frame: 87/100 -  Tracked points : 200
# Frame: 88/100 -  Tracked points : 166
# Frame: 89/100 -  Tracked points : 147
# Frame: 90/100 -  Tracked points : 159
# Frame: 91/100 -  Tracked points : 151
# Frame: 92/100 -  Tracked points : 165
# Frame: 93/100 -  Tracked points : 154
# Frame: 94/100 -  Tracked points : 200
# Frame: 95/100 -  Tracked points : 200
# Frame: 96/100 -  Tracked points : 200
# Frame: 97/100 -  Tracked points : 169
# Frame: 0/100 -  Tracked points : 199
# Frame: 1/100 -  Tracked points : 200
# Frame: 2/100 -  Tracked points : 200
# Frame: 3/100 -  Tracked points : 200
# Frame: 4/100 -  Tracked points : 200
# Frame: 5/100 -  Tracked points : 200
# Frame: 6/100 -  Tracked points : 200
# Frame: 7/100 -  Tracked points : 200
# Frame: 8/100 -  Tracked points : 199
# Frame: 9/100 -  Tracked points : 200
# Frame: 10/100 -  Tracked points : 200
# Frame: 11/100 -  Tracked points : 200
# Frame: 12/100 -  Tracked points : 200
# Frame: 13/100 -  Tracked points : 199
# Frame: 14/100 -  Tracked points : 200
# Frame: 15/100 -  Tracked points : 200
# Frame: 16/100 -  Tracked points : 200
# Frame: 17/100 -  Tracked points : 200
# Frame: 18/100 -  Tracked points : 200
# Frame: 19/100 -  Tracked points : 198
# Frame: 20/100 -  Tracked points : 200
# Frame: 21/100 -  Tracked points : 200
# Frame: 22/100 -  Tracked points : 200
# Frame: 23/100 -  Tracked points : 199
# Frame: 24/100 -  Tracked points : 199
# Frame: 25/100 -  Tracked points : 200
# Frame: 26/100 -  Tracked points : 200
# Frame: 27/100 -  Tracked points : 200
# Frame: 28/100 -  Tracked points : 200
# Frame: 29/100 -  Tracked points : 199
# Frame: 30/100 -  Tracked points : 200
# Frame: 31/100 -  Tracked points : 199
# Frame: 32/100 -  Tracked points : 200
# Frame: 33/100 -  Tracked points : 199
# Frame: 34/100 -  Tracked points : 200
# Frame: 35/100 -  Tracked points : 200
# Frame: 36/100 -  Tracked points : 200
# Frame: 37/100 -  Tracked points : 199
# Frame: 38/100 -  Tracked points : 199
# Frame: 39/100 -  Tracked points : 200
# Frame: 40/100 -  Tracked points : 200
# Frame: 41/100 -  Tracked points : 200
# Frame: 42/100 -  Tracked points : 200
# Frame: 43/100 -  Tracked points : 200
# Frame: 44/100 -  Tracked points : 200
# Frame: 45/100 -  Tracked points : 200
# Frame: 46/100 -  Tracked points : 200
# Frame: 47/100 -  Tracked points : 200
# Frame: 48/100 -  Tracked points : 200
# Frame: 49/100 -  Tracked points : 200
# Frame: 50/100 -  Tracked points : 200
# Frame: 51/100 -  Tracked points : 200
# Frame: 52/100 -  Tracked points : 200
# Frame: 53/100 -  Tracked points : 199
# Frame: 54/100 -  Tracked points : 200
# Frame: 55/100 -  Tracked points : 200
# Frame: 56/100 -  Tracked points : 199
# Frame: 57/100 -  Tracked points : 199
# Frame: 58/100 -  Tracked points : 200
# Frame: 59/100 -  Tracked points : 200
# Frame: 60/100 -  Tracked points : 200
# Frame: 61/100 -  Tracked points : 200
# Frame: 62/100 -  Tracked points : 200
# Frame: 63/100 -  Tracked points : 200
# Frame: 64/100 -  Tracked points : 200
# Frame: 65/100 -  Tracked points : 200
# Frame: 66/100 -  Tracked points : 200
# Frame: 67/100 -  Tracked points : 199
# Frame: 68/100 -  Tracked points : 199
# Frame: 69/100 -  Tracked points : 200
# Frame: 70/100 -  Tracked points : 200
# Frame: 71/100 -  Tracked points : 199
# Frame: 72/100 -  Tracked points : 197
# Frame: 73/100 -  Tracked points : 200
# Frame: 74/100 -  Tracked points : 200
# Frame: 75/100 -  Tracked points : 200
# Frame: 76/100 -  Tracked points : 200
# Frame: 77/100 -  Tracked points : 200
# Frame: 78/100 -  Tracked points : 200
# Frame: 79/100 -  Tracked points : 200
# Frame: 80/100 -  Tracked points : 200
# Frame: 81/100 -  Tracked points : 200
# Frame: 82/100 -  Tracked points : 199
# Frame: 83/100 -  Tracked points : 199
# Frame: 84/100 -  Tracked points : 199
# Frame: 85/100 -  Tracked points : 200
# Frame: 86/100 -  Tracked points : 200
# Frame: 87/100 -  Tracked points : 199
# Frame: 88/100 -  Tracked points : 197
# Frame: 89/100 -  Tracked points : 200
# Frame: 90/100 -  Tracked points : 199
# Frame: 91/100 -  Tracked points : 197
# Frame: 92/100 -  Tracked points : 200
# Frame: 93/100 -  Tracked points : 200
# Frame: 94/100 -  Tracked points : 199
# Frame: 95/100 -  Tracked points : 200
# Frame: 96/100 -  Tracked points : 200
# Frame: 97/100 -  Tracked points : 200
# Frame: 0/86 -  Tracked points : 172
# Frame: 1/86 -  Tracked points : 170
# Frame: 2/86 -  Tracked points : 171
# Frame: 3/86 -  Tracked points : 172
# Frame: 4/86 -  Tracked points : 172
# Frame: 5/86 -  Tracked points : 172
# Frame: 6/86 -  Tracked points : 173
# Frame: 7/86 -  Tracked points : 172
# Frame: 8/86 -  Tracked points : 173
# Frame: 9/86 -  Tracked points : 172
# Frame: 10/86 -  Tracked points : 172
# Frame: 11/86 -  Tracked points : 170
# Frame: 12/86 -  Tracked points : 170
# Frame: 13/86 -  Tracked points : 170
# Frame: 14/86 -  Tracked points : 170
# Frame: 15/86 -  Tracked points : 169
# Frame: 16/86 -  Tracked points : 168
# Frame: 17/86 -  Tracked points : 171
# Frame: 18/86 -  Tracked points : 171
# Frame: 19/86 -  Tracked points : 166
# Frame: 20/86 -  Tracked points : 183
# Frame: 21/86 -  Tracked points : 186
# Frame: 22/86 -  Tracked points : 174
# Frame: 23/86 -  Tracked points : 176
# Frame: 24/86 -  Tracked points : 169
# Frame: 25/86 -  Tracked points : 161
# Frame: 26/86 -  Tracked points : 171
# Frame: 27/86 -  Tracked points : 164
# Frame: 28/86 -  Tracked points : 184
# Frame: 29/86 -  Tracked points : 173
# Frame: 30/86 -  Tracked points : 170
# Frame: 31/86 -  Tracked points : 171
# Frame: 32/86 -  Tracked points : 171
# Frame: 33/86 -  Tracked points : 173
# Frame: 34/86 -  Tracked points : 173
# Frame: 35/86 -  Tracked points : 176
# Frame: 36/86 -  Tracked points : 178
# Frame: 37/86 -  Tracked points : 176
# Frame: 38/86 -  Tracked points : 173
# Frame: 39/86 -  Tracked points : 176
# Frame: 40/86 -  Tracked points : 177
# Frame: 41/86 -  Tracked points : 175
# Frame: 42/86 -  Tracked points : 176
# Frame: 43/86 -  Tracked points : 177
# Frame: 44/86 -  Tracked points : 178
# Frame: 45/86 -  Tracked points : 179
# Frame: 46/86 -  Tracked points : 180
# Frame: 47/86 -  Tracked points : 180
# Frame: 48/86 -  Tracked points : 181
# Frame: 49/86 -  Tracked points : 175
# Frame: 50/86 -  Tracked points : 177
# Frame: 51/86 -  Tracked points : 179
# Frame: 52/86 -  Tracked points : 179
# Frame: 53/86 -  Tracked points : 178
# Frame: 54/86 -  Tracked points : 175
# Frame: 55/86 -  Tracked points : 175
# Frame: 56/86 -  Tracked points : 173
# Frame: 57/86 -  Tracked points : 172
# Frame: 58/86 -  Tracked points : 172
# Frame: 59/86 -  Tracked points : 174
# Frame: 60/86 -  Tracked points : 175
# Frame: 264/313 -  Tracked points : 40
# Frame: 265/313 -  Tracked points : 42
# Frame: 266/313 -  Tracked points : 43
# Frame: 267/313 -  Tracked points : 42
# Frame: 268/313 -  Tracked points : 44
# Frame: 269/313 -  Tracked points : 44
# Frame: 270/313 -  Tracked points : 42
# Frame: 271/313 -  Tracked points : 45
# Frame: 272/313 -  Tracked points : 45
# Frame: 273/313 -  Tracked points : 46
# Frame: 274/313 -  Tracked points : 48
# Frame: 275/313 -  Tracked points : 43
# Frame: 276/313 -  Tracked points : 40
# Frame: 277/313 -  Tracked points : 41
# Frame: 278/313 -  Tracked points : 40
# Frame: 279/313 -  Tracked points : 39
# Frame: 280/313 -  Tracked points : 37
# Frame: 281/313 -  Tracked points : 34
# Frame: 282/313 -  Tracked points : 35
# Frame: 283/313 -  Tracked points : 32
# Frame: 284/313 -  Tracked points : 33
# Frame: 285/313 -  Tracked points : 34
# Frame: 286/313 -  Tracked points : 34
# Frame: 287/313 -  Tracked points : 33
# Frame: 288/313 -  Tracked points : 35
# Frame: 289/313 -  Tracked points : 36
# Frame: 290/313 -  Tracked points : 34
# Frame: 291/313 -  Tracked points : 28
# Frame: 292/313 -  Tracked points : 28
# Frame: 293/313 -  Tracked points : 27
# Frame: 294/313 -  Tracked points : 30
# Frame: 295/313 -  Tracked points : 30
# Frame: 296/313 -  Tracked points : 34
# Frame: 297/313 -  Tracked points : 30
# Frame: 298/313 -  Tracked points : 32
# Frame: 299/313 -  Tracked points : 27
# Frame: 300/313 -  Tracked points : 26
# Frame: 301/313 -  Tracked points : 26
# Frame: 302/313 -  Tracked points : 28
# Frame: 303/313 -  Tracked points : 30
# Frame: 304/313 -  Tracked points : 30
# Frame: 305/313 -  Tracked points : 28
# Frame: 306/313 -  Tracked points : 30
# Frame: 307/313 -  Tracked points : 29
# Frame: 308/313 -  Tracked points : 30
# Frame: 309/313 -  Tracked points : 29
# Frame: 310/313 -  Tracked points : 29

# %% [markdown]
# # Gaussian kernel low-pass filter on camera motion (ffmpeg)

# %%
import subprocess
videos=os.listdir("./samples")
transform_file = "transform_vectors.trf"
for video in videos:
  input_file=os.path.join("./samples",video)
  output_file=os.path.join("./ffmpeg",video.replace(".mp4","_stabilized.mp4"))
  command = ["ffmpeg", "-i", input_file, "-vf", f"vidstabdetect=stepsize=6:shakiness=8:accuracy=9:result={transform_file}", "-f", "null", "-"]
  subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  command = ["ffmpeg", "-i", input_file, "-vf", f"vidstabtransform=input={transform_file}", "-c:a", "copy", output_file]
  subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# %% [markdown]
# # Stabilization using vidstab package

# %%
from vidstab import VidStab
import matplotlib.pyplot as plt
videos=os.listdir("./samples")
for video in videos:
  input_file=os.path.join("./samples",video)
  output_file=os.path.join("./vidstab",video.replace(".mp4","_stabilized.mp4"))
  stabilizer = VidStab()
  stabilizer.stabilize(input_path=input_file, output_path=output_file)

# %% [markdown]
# The results are stored in the folder results (https://github.com/centralelyon/video-stabilization/tree/main/results).
